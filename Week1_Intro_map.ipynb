# %% [markdown]
# <a href="https://colab.research.google.com/github/HowardChen0211/gisPy/blob/main/Week1_Intro_map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#  !pip install geopandas

# %%
gpd.__version__
# Out:
# '1.1.4'

# %%
import os, zipfile
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd

import mapclassify # need for thematic map classification

#will display all output not just last command
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# shp is a form of 向量資料
gdf_Rail = gpd.read_file("/content/drive/MyDrive/GIS_2026 Fall/Rail/RAIL.shp", encoding = "utf-8")
gdf_Rail.head()
# Out:
#         RAILID   RAILNAME  RAILTYPE   MDATE  DEFINITION  \
# 0  O0000000001      臺鐵內灣線         2  201311           0
# 1  O0000000002      臺鐵內灣線         2  201311           0
# 2  O0000000003  臺鐵海岸線(海線)         2  201311           0
# 3  P0000000004    臺鐵縱貫線南段         2  201609           0
# 4  P0000000003    臺鐵縱貫線南段         2  201608           0
#
#                                             geometry
# 0  LINESTRING (248537.856 2744654.392, 248582.66 ...
# 1  LINESTRING (252762.399 2741652.649, 252762.087...
# 2  LINESTRING (238293.482 2736274.722, 238293.707...
# 3  LINESTRING (198052.863 2620124.003, 198062.309...
# 4  LINESTRING (197498.964 2619431.837, 197581.785...

# %%
sample = gdf_Rail.sort_values(by="MDATE")
sample.head()
# Out:
#           RAILID RAILNAME  RAILTYPE   MDATE  DEFINITION  \
# 605  M0000000006    臺鐵集集線         2  200903           0
# 603  M0000000004    臺鐵集集線         2  200903           0
# 604  M0000000005    臺鐵集集線         2  200903           0
# 606  M0000000007    臺鐵集集線         2  200903           0
# 607  M0000000008    臺鐵集集線         2  200903           0
#
#                                               geometry
# 605  LINESTRING (227966.379 2635798.635, 227958.213...
# 603  LINESTRING (227986.868 2635797.885, 228002.272...
# 604  LINESTRING (227966.379 2635798.635, 227990.984...
# 606  LINESTRING (227991.07 2635800.179, 227991.446 ...
# 607  LINESTRING (227991.07 2635800.179, 227991.348 ...

# %%
# !wget -q -O nj-counties.zip https://docs.google.com/uc?id=1xJDhcRCkgv7k4tNCa72Oog5bohV6dTB2&export=download

# %%
zip_ref = zipfile.ZipFile('/content/nj-counties.zip', 'r'); zip_ref.extractall(); zip_ref.close() #just unzipping
njC0=gpd.read_file('nj_counties.shp') #load the shapefile with gpd as njC
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# /tmp/ipykernel_1599/853807459.py in <cell line: 0>()
# ----> 1 zip_ref = zipfile.ZipFile('/content/nj-counties.zip', 'r'); zip_ref.extractall(); zip_ref.close() #just unzipping
#       2 njC0=gpd.read_file('nj_counties.shp') #load the shapefile with gpd as njC
#
# /usr/lib/python3.12/zipfile/__init__.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1368         try:
#    1369             if mode == 'r':
# -> 1370                 self._RealGetContents()
#    1371             elif mode in ('w', 'x'):
#    1372                 # set the modified flag so central directory gets written
#
# /usr/lib/python3.12/zipfile/__init__.py in _RealGetContents(self)
#    1435             raise BadZipFile("File is not a zip file")
#    1436         if not endrec:
# ...
